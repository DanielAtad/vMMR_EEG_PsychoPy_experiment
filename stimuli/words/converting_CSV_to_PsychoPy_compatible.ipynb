# %%
import os

files = ['death_words.csv', 'negative_words.csv', 'neutral_words.csv']

for fname in files:
    # Read with original Windows-1255 encoding
    with open(fname, 'r', encoding='windows-1255') as f:
        content = f.read()
    
    # Strip any leading/trailing whitespace from each word
    words = [w.strip() for w in content.strip().splitlines() if w.strip()]
    
    # Write back as UTF-8 with header
    with open(fname, 'w', encoding='utf-8', newline='\n') as f:
        f.write('word\n')
        f.write('\n'.join(words))
        f.write('\n')
    
    print(f"{fname}: {len(words)} words, re-saved as UTF-8")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       3 files = ['death_words.csv', 'negative_words.csv', 'neutral_words.csv']
#       5 for fname in files:
#       6     # Read with original Windows-1255 encoding
# ----> 7     with open(fname, 'r', encoding='windows-1255') as f:
#       8         content = f.read()
#      10     # Strip any leading/trailing whitespace from each word
#
# File c:\Users\omer\anaconda3\envs\vmmr-eeg\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'death_words.csv'
